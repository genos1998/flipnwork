# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementNotInteractableException
import ipyparallel as ipp

# %%
link=pd.read_csv('cardekho_link.csv')
link

# %%
urls=list(link['url'].values[4000:4100])
year=[]
fuel=[]
kms=[]
owners=[]
transmission=[]
price=[]
mileage=[]
engine=[]
power=[]
seats=[]
gear=[]
drive=[]
steering=[]
torque=[]
values_cylinder=[]
no_cylinder=[]
turbo=[]
super_charger=[]
i=0
driver=webdriver.Chrome('chromedriver.exe')
for url in urls:
    driver.get(url)
    time.sleep(3)
    driver.execute_script("window.scrollBy(0,1000)")
    time.sleep(2)
    driver.execute_script("window.scrollBy(0,500)")
    time.sleep(2)
    try:
        view=driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[4]/div/div/div/div/div[2]/a')
        view.click()
        time.sleep(2)
    except:
        try:
            if driver.find_element_by_xpath('//div[@class="hover whatsappShare margt25 shareButton"]').text=='View All Specifications':
                button=driver.find_element_by_xpath('//div[@class="hover whatsappShare margt25 shareButton"]')
                button.click()
                time.sleep(2) 
        except:
            pass
        #--year--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[2]/div/div[2]')      
        year.append(ear.text)
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[3]/div/div/div/div[1]/ul/li[1]/div/div')      
            year.append(ear.text) 
        except:
            year.append('-')
        #--fuel--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[3]/div/div[2]')      
        fuel.append(ear.text)
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[3]/div/div/div/div[1]/ul/li[5]/div/div') 
            fuel.append(ear.text) 
        except:
            fuel.append('-')
    #--kms--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[4]/div/div[2]')      
        kms.append(ear.text)
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[3]/div/div/div/div[1]/ul/li[3]/div/div') 
            kms.append(ear.text) 
        except:
            kms.append('-')
    #--owners--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[6]/div/div[2]')      
        owners.append(ear.text)
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[3]/div/div/div/div[1]/ul/li[4]/div/div') 
            owners.append(ear.text) 
        except:
            owners.append('-')
    #--transmission--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[3]/div/div/div/ul/li[8]/div/div[2]')      
        transmission.append(ear.text)
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[3]/div/div/div/div[1]/ul/li[6]/div/div') 
            transmission.append(ear.text) 
        except:
            transmission.append('-')
    #--price--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[2]/div[1]/div/div/div/div[1]/div[2]/div/div[1]/span[2]')      
        price.append(ear.text)
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[2]/div[2]/div/div/div/div[1]/span/span') 
            price.append(ear.text) 
        except:
            price.append('-')
    #--mileage--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[1]/div/div[2]')      
        mileage.append(ear.text)
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[4]/div/div/div/div/div[1]/div/div/div[2]/div[1]/div/section/div/div/ul/li[1]/div[2]') 
            mileage.append(ear.text) 
        except:
            mileage.append('-')
    #--engine--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[2]/div/div[2]')      
        engine.append(ear.text)
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[4]/div/div/div/div/div[1]/div/div/div[2]/div[1]/div/section/div/div/ul/li[2]/div[2]') 
            engine.append(ear.text) 
        except:
            engine.append('-')
    #--power--
    try:
        if driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[22]/div/div[1]').text=='Max Power':
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[22]/div/div[2]')
            power.append(ear.text)
        else:
            raise NoSuchElementException
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[4]/div/div/div/div/div[1]/div/div/div[2]/div[1]/div/section/div/div/ul/li[23]/div[2]') 
            power.append(ear.text) 
        except:
            power.append('-')
    #--seats--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[9]/div/div[2]')
        if driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[9]/div/div[1]').text=='Seating Capacity':
            seats.append(ear.text)
        else:
            raise NoSuchElementException
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[4]/div/div/div/div/div[1]/div/div/div[2]/div[1]/div/section/div/div/ul/li[9]/div[2]') 
            seats.append(ear.text) 
        except:
            seats.append('-')
    #--gear--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[7]/div/div[2]')
        if driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[7]/div/div[1]').text=='Gear Box':
            gear.append(ear.text)
        else:
            raise NoSuchElementException
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[4]/div/div/div/div/div[1]/div/div/div[2]/div[1]/div/section/div/div/ul/li[7]/div[2]') 
            gear.append(ear.text) 
        except:
            gear.append('-')
    #--drive--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[8]/div/div[2]')      
        if driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[8]/div/div[1]').text=='Drive Type':
            drive.append(ear.text)
        else:
            raise NoSuchElementException
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[4]/div/div/div/div/div[1]/div/div/div[2]/div[1]/div/section/div/div/ul/li[8]/div[2]') 
            drive.append(ear.text) 
        except:
            drive.append('-')
    #--steering--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[10]/div/div[2]')      
        if driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[10]/div/div[1]').text=='Steering Type':
            steering.append(ear.text)
        else:
            raise NoSuchElementException
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[4]/div/div/div/div/div[1]/div/div/div[2]/div[1]/div/section/div/div/ul/li[11]/div[2]') 
            steering.append(ear.text) 
        except:
            steering.append('-')
    #--no_cylinder--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[24]/div/div[2]')      
        if driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[24]/div/div[1]').text=='No of Cylinder':
            no_cylinder.append(ear.text)
        else:
            raise NoSuchElementException
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[4]/div/div/div/div/div[1]/div/div/div[2]/div[1]/div/section/div/div/ul/li[25]/div[2]') 
            no_cylinder.append(ear.text) 
        except:
            no_cylinder.append('-')
    #--values_cylinder--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[25]/div/div[2]')      
        if driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[25]/div/div[1]').text=='Values per Cylinder':    
            values_cylinder.append(ear.text)
        else:
            raise NoSuchElementException
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[4]/div/div/div/div/div[1]/div/div/div[2]/div[1]/div/section/div/div/ul/li[26]/div[2]') 
            values_cylinder.append(ear.text) 
        except:
            values_cylinder.append('-')
    #--torque--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[23]/div/div[2]')      
        if driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[23]/div/div[1]').text=='Max Torque':
            torque.append(ear.text)
        else:
            raise NoSuchElementException
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[4]/div/div/div/div/div[1]/div/div/div[2]/div[1]/div/section/div/div/ul/li[24]/div[2]') 
            torque.append(ear.text) 
        except:
            torque.append('-')
    #--turbo--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[28]/div/div[2]')      
        if driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[28]/div/div[1]').text=='Turbo Charger':
            turbo.append(ear.text)
        else:
            raise NoSuchElementException
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[4]/div/div/div/div/div[1]/div/div/div[2]/div[1]/div/section/div/div/ul/li[31]/div[2]') 
            turbo.append(ear.text) 
        except:
            turbo.append('-')
    #--super--
    try:
        ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[29]/div/div[2])      
        if driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div/div/div[1]/div[6]/div/div/div/ul/li[29]/div/div[1]').text=='Super Charger':
            super_charger.append(ear.text)
        else:
            raise NoSuchElementException
    except NoSuchElementException:
        try:
            ear = driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/div/div/main/div[2]/div[1]/div/div[4]/div/div/div/div/div[1]/div/div/div[2]/div[1]/div/section/div/div/ul/li[32]/div[2]') 
            super_charger.append(ear.text) 
        except:
            super_charger.append('-')
    i+=1
    print(i,end=', ')
    #print(year,fuel,kms,owners,transmission,price,mileage,engine,power,seats,gear,drive,steering,torque,values_cylinder,no_cylinder,turbo,super_charger)
