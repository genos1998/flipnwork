# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pandas as pd
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings("ignore")
import seaborn as sn
import numpy as np
import scipy.stats as stats
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler,power_transform
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,BaggingRegressor,ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR,NuSVR,LinearSVR
from sklearn.linear_model import LinearRegression,Ridge,RidgeCV,BayesianRidge,SGDRegressor,LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.svm import NuSVR
from sklearn.impute import KNNImputer
from sklearn.cluster import KMeans
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor,XGBRFRegressor
from mlxtend.regressor import StackingCVRegressor
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.feature_selection import RFE
from sklearn.preprocessing import PowerTransformer
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
from datetime import date
import random
import calendar
from datetime import date
import joblib
import math
# %matplotlib inline

# %%
data_I=pd.read_csv('data_I.csv')
data_II=pd.read_csv('data_II.csv')
data_III=pd.read_csv('data_III.csv')
pd.set_option('max_columns', None)
data_I
# Out:
#        Unnamed: 0  Date  Month      Name Depart Times Departure Arrival Times  \
# 0               0     1      1  Air Asia        15:50   Chennai         17:00
# 1               1     1      1  Air Asia        22:35   Chennai         23:45
# 2               2     1      1    IndiGo        05:25   Chennai         06:25
# 3               3     1      1    IndiGo        13:05   Chennai         14:10
# 4               4     1      1    IndiGo        16:30   Chennai         17:35
# ...           ...   ...    ...       ...          ...       ...           ...
# 11205       11205     1      2   Vistara        19:45    Mumbai         13:50
# 11206       11206     1      2   Vistara        19:45    Mumbai         21:20
# 11207       11207     1      2  Go First        23:45    Mumbai         13:30
# 11208       11208     1      2  Go First        22:40    Mumbai         13:30
# 11209       11209     1      2  Go First        21:15    Mumbai         13:30
#
#          Arrival Duration No. of Stops   price
# 0      Bangalore   1h 10m     Non Stop   1,443
# 1      Bangalore   1h 10m     Non Stop   1,443
# 2      Bangalore   1h 00m     Non Stop   1,444
# 3      Bangalore   1h 05m     Non Stop   1,444
# 4      Bangalore   1h 05m     Non Stop   1,444
# ...          ...      ...          ...     ...
# 11205        Goa  18h 05m       1 Stop  11,414
# 11206        Goa  25h 35m       1 Stop  11,414
# 11207        Goa  13h 45m       1 Stop  12,223
# 11208        Goa  14h 50m       1 Stop  12,223
# 11209        Goa  16h 15m       1 Stop  12,223
#
# [11210 rows x 11 columns]

# %%
data_II
# Out:
#        Unnamed: 0  Date  Month       Name Depart Times  Departure  \
# 0               0     1      1   SpiceJet        06:15  New Delhi
# 1               1     1      1  Air India        06:10  New Delhi
# 2               2     1      1    Vistara        10:00  New Delhi
# 3               3     1      1    Vistara        07:30  New Delhi
# 4               4     1      1   Air Asia        08:00  New Delhi
# ...           ...   ...    ...        ...          ...        ...
# 10669       10669     1      2    Vistara        20:15  Ahmedabad
# 10670       10670     1      2   Go First        22:05  Ahmedabad
# 10671       10671     1      2    Vistara        20:15  Ahmedabad
# 10672       10672     1      2    Vistara        20:15  Ahmedabad
# 10673       10673     1      2    Vistara        20:15  Ahmedabad
#
#       Arrival Times    Arrival Duration No. of Stops   price
# 0             21:10  Bangalore  14h 55m       1 Stop   3,993
# 1             08:55  Bangalore   2h 45m     Non Stop   4,007
# 2             08:50  Bangalore  22h 50m       1 Stop   4,034
# 3             08:50  Bangalore  25h 20m       1 Stop   4,034
# 4             10:40  Bangalore   2h 40m     Non Stop   4,199
# ...             ...        ...      ...          ...     ...
# 10669         21:20        Goa  25h 05m       1 Stop  11,215
# 10670         13:30        Goa  15h 25m       1 Stop  11,871
# 10671         14:05        Goa  17h 50m    2 Stop(s)  12,636
# 10672         14:05        Goa  17h 50m    2 Stop(s)  12,636
# 10673         14:05        Goa  17h 50m    2 Stop(s)  12,847
#
# [10674 rows x 11 columns]

# %%
data_III
# Out:
#        Unnamed: 0  Date  Month       Name Depart Times Departure  \
# 0               0     1      1     IndiGo        02:30       Goa
# 1               1     1      1     IndiGo        03:35       Goa
# 2               2     1      1     IndiGo        03:35       Goa
# 3               3     1      1     IndiGo        06:25       Goa
# 4               4     1      1    Vistara        00:20       Goa
# ...           ...   ...    ...        ...          ...       ...
# 10488       10488    15      2  Air India        13:30    Jaipur
# 10489       10489    15      2   Air Asia        23:50    Jaipur
# 10490       10490    15      2  Air India        20:35    Jaipur
# 10491       10491    15      2     IndiGo        07:45    Jaipur
# 10492       10492    15      2     IndiGo        08:40    Jaipur
#
#       Arrival Times    Arrival Duration No. of Stops  price
# 0             03:45  Bangalore   1h 15m     Non Stop  4,161
# 1             07:55  Bangalore   4h 20m       1 Stop  4,424
# 2             10:15  Bangalore   6h 40m       1 Stop  4,424
# 3             07:40  Bangalore   1h 15m     Non Stop  5,736
# 4             07:50  Bangalore   7h 30m       1 Stop  6,556
# ...             ...        ...      ...          ...    ...
# 10488         13:15        Goa  23h 45m       1 Stop  7,079
# 10489         07:50        Goa   8h 00m       1 Stop  7,227
# 10490         13:15        Goa  16h 40m       1 Stop  7,299
# 10491         14:35        Goa   6h 50m       1 Stop  7,383
# 10492         17:20        Goa   8h 40m       1 Stop  7,999
#
# [10493 rows x 11 columns]

# %%
data_I=data_I.drop(['Unnamed: 0'],axis=1)
data_II=data_II.drop(['Unnamed: 0'],axis=1)
data_III=data_III.drop(['Unnamed: 0'],axis=1)

# %%
data=pd.concat([data_I,data_II,data_III])
data
# Out:
#        Date  Month       Name Depart Times Departure Arrival Times    Arrival  \
# 0         1      1   Air Asia        15:50   Chennai         17:00  Bangalore
# 1         1      1   Air Asia        22:35   Chennai         23:45  Bangalore
# 2         1      1     IndiGo        05:25   Chennai         06:25  Bangalore
# 3         1      1     IndiGo        13:05   Chennai         14:10  Bangalore
# 4         1      1     IndiGo        16:30   Chennai         17:35  Bangalore
# ...     ...    ...        ...          ...       ...           ...        ...
# 10488    15      2  Air India        13:30    Jaipur         13:15        Goa
# 10489    15      2   Air Asia        23:50    Jaipur         07:50        Goa
# 10490    15      2  Air India        20:35    Jaipur         13:15        Goa
# 10491    15      2     IndiGo        07:45    Jaipur         14:35        Goa
# 10492    15      2     IndiGo        08:40    Jaipur         17:20        Goa
#
#       Duration No. of Stops  price
# 0       1h 10m     Non Stop  1,443
# 1       1h 10m     Non Stop  1,443
# 2       1h 00m     Non Stop  1,444
# 3       1h 05m     Non Stop  1,444
# 4       1h 05m     Non Stop  1,444
# ...        ...          ...    ...
# 10488  23h 45m       1 Stop  7,079
# 10489   8h 00m       1 Stop  7,227
# 10490  16h 40m       1 Stop  7,299
# 10491   6h 50m       1 Stop  7,383
# 10492   8h 40m       1 Stop  7,999
#
# [32377 rows x 10 columns]

# %% [markdown]
# ### Reset index of data

# %%
data=data.reset_index(drop=True)

# %%
data[['Name','Departure','Arrival','No. of Stops']].describe()
# Out:
#              Name  Departure  Arrival No. of Stops
# count       32377      32377    32377        32377
# unique          7          9        9            5
# top     Air India  New Delhi  Kolkata       1 Stop
# freq         9003       4038     4865        21828

# %% [markdown]
# ### Replace ',' in price column
# ### conv duration to mins only
# ### conv no. of stops to numeric value
# ### conv date and month to no. of days from today till departure (as the price will differ on how advancedly the ticket is booked)

# %%
for i in range(len(data['price'])):
    data['price'].iloc[i]=int(data['price'].iloc[i].replace(',',''))

# %%
for i in range(len(data['Duration'])):
    hour=int(data['Duration'].iloc[i].split()[0].replace('h',''))
    minute=int(data['Duration'].iloc[i].split()[1].replace('m',''))
    timex=(hour*60)+minute
    data['Duration'].iloc[i]=timex

# %%
for i in range(len(data['Depart Times'])):
    hour=int(data['Depart Times'].iloc[i].replace(':',' ').split()[0].replace('h',''))
    minute=int(data['Depart Times'].iloc[i].replace(':',' ').split()[1].replace('m',''))
    timex=(hour*60)+minute
    data['Depart Times'].iloc[i]=timex
    
    hour=int(data['Arrival Times'].iloc[i].replace(':',' ').split()[0].replace('h',''))
    minute=int(data['Arrival Times'].iloc[i].replace(':',' ').split()[1].replace('m',''))
    timex=(hour*60)+minute
    data['Arrival Times'].iloc[i]=timex

# %%
data['Days']=0

# %%
def numOfDays(date1, date2):
    return (date1-date2).days

# %%
dated=date.today()
dated
# Out:
# datetime.date(2021, 11, 25)

# %%
for i in range(len(data['Date'])):
    date1=date(2022,data['Month'][i],data['Date'][i])
    date2 = dated
    data['Days'].iloc[i]=numOfDays(date1, date2)

# %%
data=data.drop(['Date','Month'],axis=1)

# %%
for i in range(len(data['No. of Stops'])):
    if data['No. of Stops'][i].split()[0]=='Non':
        data['No. of Stops'].iloc[i]=0
    else:
        data['No. of Stops'].iloc[i]=int(data['No. of Stops'][i].split()[0])

# %%
listy=list(set(data.Departure.values))
misty=list(set(data.Arrival.values))
listy.extend(misty)
unique=list(set(listy))
dicty={}
for i in range(len(unique)):
    dicty[unique[i]]=i+1
print(dicty)
# Out:
# {'Goa': 1, 'Chennai': 2, 'Pune': 3, 'New Delhi': 4, 'Agra': 5, 'Jaipur': 6, 'Kolkata': 7, 'Bangalore': 8, 'Hyderabad': 9, 'Ahmedabad': 10, 'Mumbai': 11}

# %%
for i in range(len(data.Departure)):
    data['Departure'].iloc[i]=dicty[data['Departure'][i]]
    data['Arrival'].iloc[i]=dicty[data['Arrival'][i]]

# %%
listy=list(set(data.Name.values))
dicty={}
for i in range(len(listy)):
    dicty[listy[i]]=i+1
print(dicty)
# Out:
# {'IndiGo': 1, 'Air Asia': 2, 'SpiceJet': 3, 'Go First': 4, 'Vistara': 5, 'Air India': 6, 'TruJet': 7}

# %%
for i in range(len(data.Name)):
    data['Name'].iloc[i]=dicty[data['Name'][i]]

# %%
data['Name'] = data['Name'].astype(int)
data['Depart Times'] = data['Depart Times'].astype(int)
data['Departure'] = data['Departure'].astype(int)
data['Arrival Times'] = data['Arrival Times'].astype(int)
data['Arrival'] = data['Arrival'].astype(int)
data['Duration'] = data['Duration'].astype(int)
data['No. of Stops'] = data['No. of Stops'].astype(int)
data['Days']=data['Days'].astype(int)
data['price'] = data['price'].astype(int)

# %% [markdown]
# ### drop column arrival times

# %%
data=data.drop(['Arrival Times'],axis=1)

# %%
data[data.duplicated()]
# Out:
#        Name  Depart Times  Departure  Arrival  Duration  No. of Stops  price  \
# 51        6          1220          2        8      1410             2  10025
# 53        6           595          2        8      2035             2  10025
# 67        6          1020          2        8      1610             2  12545
# 175       6           805          2       11      1405             2  10054
# 383       5           585          2        9      2110             2   6398
# ...     ...           ...        ...      ...       ...           ...    ...
# 32352     6           225          6        1       660             2   6126
# 32353     6           225          6        1       660             2   6126
# 32355     6           810          6        1      1040             2   6126
# 32356     6           810          6        1      1040             2   6126
# 32363     6           225          6        1      1005             2   6452
#
#        Days
# 51       37
# 53       37
# 67       37
# 175      37
# 383      37
# ...     ...
# 32352    82
# 32353    82
# 32355    82
# 32356    82
# 32363    82
#
# [1165 rows x 8 columns]

# %%
data=data.drop_duplicates()
data
# Out:
#        Name  Depart Times  Departure  Arrival  Duration  No. of Stops  price  \
# 0         2           950          2        8        70             0   1443
# 1         2          1355          2        8        70             0   1443
# 2         1           325          2        8        60             0   1444
# 3         1           785          2        8        65             0   1444
# 4         1           990          2        8        65             0   1444
# ...     ...           ...        ...      ...       ...           ...    ...
# 32372     6           810          6        1      1425             1   7079
# 32373     2          1430          6        1       480             1   7227
# 32374     6          1235          6        1      1000             1   7299
# 32375     1           465          6        1       410             1   7383
# 32376     1           520          6        1       520             1   7999
#
#        Days
# 0        37
# 1        37
# 2        37
# 3        37
# 4        37
# ...     ...
# 32372    82
# 32373    82
# 32374    82
# 32375    82
# 32376    82
#
# [31212 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31212 entries, 0 to 32376
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          31212 non-null  int32
#  1   Depart Times  31212 non-null  int32
#  2   Departure     31212 non-null  int32
#  3   Arrival       31212 non-null  int32
#  4   Duration      31212 non-null  int32
#  5   No. of Stops  31212 non-null  int32
#  6   price         31212 non-null  int32
#  7   Days          31212 non-null  int32
# dtypes: int32(8)
# memory usage: 1.2 MB

# %%
data[['Depart Times','Duration','price']].describe()
# Out:
#        Depart Times      Duration         price
# count  31212.000000  31212.000000  31212.000000
# mean     783.776112    673.386037   5695.290529
# std      361.877427    448.391672   2828.261972
# min        5.000000     50.000000   1443.000000
# 25%      465.000000    360.000000   3988.000000
# 50%      785.000000    565.000000   5078.000000
# 75%     1130.000000    900.000000   6742.250000
# max     1435.000000   2675.000000  39115.000000

# %%
data=data[['Name','Depart Times','Departure','Arrival','Duration','No. of Stops','Days','price']]
data
# Out:
#        Name  Depart Times  Departure  Arrival  Duration  No. of Stops  Days  \
# 0         2           950          2        8        70             0    37
# 1         2          1355          2        8        70             0    37
# 2         1           325          2        8        60             0    37
# 3         1           785          2        8        65             0    37
# 4         1           990          2        8        65             0    37
# ...     ...           ...        ...      ...       ...           ...   ...
# 32372     6           810          6        1      1425             1    82
# 32373     2          1430          6        1       480             1    82
# 32374     6          1235          6        1      1000             1    82
# 32375     1           465          6        1       410             1    82
# 32376     1           520          6        1       520             1    82
#
#        price
# 0       1443
# 1       1443
# 2       1444
# 3       1444
# 4       1444
# ...      ...
# 32372   7079
# 32373   7227
# 32374   7299
# 32375   7383
# 32376   7999
#
# [31212 rows x 8 columns]

# %% [markdown]
# ### Visualization:
# ### Univariate analysis

# %%
plt.figure(figsize=(20,300),facecolor='white')
plotnumber=1
for column in data.columns:
    if plotnumber<=len(data.columns):
        ax=plt.subplot(50,3,plotnumber)
        sn.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# ### Univariate analysis for categorical columns

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1
for i in data.columns:
    if i not in ['Duration','Depart Times'] and i!='price':
        ax=plt.subplot(6,3,plotnumber)
        sn.countplot(data[i])
        plt.xlabel(i,fontsize=20)
        plt.ylabel('Count',fontsize=20)
        plotnumber+=1
plt.tight_layout()

# %%
data['Name'].value_counts()
# Out:
# 1    8781
# 6    8381
# 5    7436
# 4    3675
# 2    1671
# 3    1258
# 7      10
# Name: Name, dtype: int64

# %% [markdown]
# ### Drop categorical value 4 of Name as it has data points less than 5% in the dataset

# %%
data=data[data['Name']!=5]

# %%
data['No. of Stops'].value_counts()
# Out:
# 1    21814
# 0     4343
# 2     4293
# 3      689
# 4       63
# Name: No. of Stops, dtype: int64

# %%
data=data[data['No. of Stops']!=4][data['No. of Stops']!=3]

# %%
data['Arrival'].value_counts()
# Out:
# 10    4571
# 2     4211
# 9     4058
# 3     4041
# 5     3707
# 1     3680
# 4     3327
# 8     2816
# 6       39
# Name: Arrival, dtype: int64

# %%
data=data[data['Arrival']!=6]

# %% [markdown]
# ### Bivariate analysis for numerical columns

# %%
sn.regplot(data['Duration'],data['price'],color='r')
plt.xlabel('Duration',fontsize=20)
plt.ylabel('price',fontsize=20)
plt.show()

# %%
sn.regplot(data['Depart Times'],data['price'],color='r')
plt.xlabel('Depart Times',fontsize=20)
plt.ylabel('price',fontsize=20)
plt.show()

# %% [markdown]
# ### stripplot for numerical columns

# %%
plt.figure(figsize=(10,10))
sn.stripplot(x=data['Duration'] , y=data['price'])
plt.title("price VS Duration",fontsize=20)
plt.xticks(fontsize=15)  
plt.yticks(fontsize=15)
plt.xlabel('Duration',fontsize = 20)
plt.ylabel('price',fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(10,10))
sn.stripplot(x=data['Depart Times'] , y=data['price'])
plt.title("price VS Depart Times",fontsize=20)
plt.xticks(fontsize=15)  
plt.yticks(fontsize=15)
plt.xlabel('Depart Times',fontsize = 20)
plt.ylabel('price',fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(20,30))
listy=data.columns
plotnumber=1
for i in range(len(listy)):
    if listy[i]!='Duration' and listy[i]!='price' and listy[i]!='Depart Times':
        plt.subplot(4,2,plotnumber)
        sn.barplot(y=data['price'],x=data[listy[i]])
        plt.title(f"price VS {listy[i]}",fontsize=40)
        plt.xticks(rotation=90,fontsize=25)  
        plt.yticks(rotation=0,fontsize=25)
        plt.xlabel(listy[i],fontsize = 30)
        plt.ylabel('price',fontsize = 30)
        plotnumber+=1
        plt.tight_layout()

# %% [markdown]
# ### Cat Plot

# %%
plt.figure(figsize=(20,30))
listy=data.columns
for i in range(len(listy)):
    if listy[i]!='price':
        sn.catplot(y=data['price'],x=data[listy[i]],data=data.sort_values("price", ascending = False), 
            kind = "boxen", height = 6, aspect = 2)
        plt.title(f"price VS {listy[i]}",fontsize=20)
        plt.show()

# %% [markdown]
# ### pair ploting for data

# %%
sn.pairplot(data,hue="price")

# %% [markdown]
# ### Multivariate Analysis

# %%
data.corr()
# Out:
#                   Name  Depart Times  Departure   Arrival  Duration  \
# Name          1.000000     -0.036172   0.096594  0.025719  0.065083
# Depart Times -0.036172      1.000000  -0.006449  0.013924  0.064540
# Departure     0.096594     -0.006449   1.000000 -0.170590  0.038027
# Arrival       0.025719      0.013924  -0.170590  1.000000 -0.002264
# Duration      0.065083      0.064540   0.038027 -0.002264  1.000000
# No. of Stops  0.062443     -0.064961   0.019314 -0.029535  0.595357
# Days          0.020674      0.012228   0.049024  0.003993 -0.010823
# price        -0.123119      0.015557  -0.014177  0.022714  0.376820
#
#               No. of Stops      Days     price
# Name              0.062443  0.020674 -0.123119
# Depart Times     -0.064961  0.012228  0.015557
# Departure         0.019314  0.049024 -0.014177
# Arrival          -0.029535  0.003993  0.022714
# Duration          0.595357 -0.010823  0.376820
# No. of Stops      1.000000 -0.003682  0.484740
# Days             -0.003682  1.000000 -0.291776
# price             0.484740 -0.291776  1.000000

# %%
plt.figure(figsize=(15,8))
sn.heatmap(data.corr(),cmap='YlGnBu',annot = True)
plt.show()

# %%
plt.figure(figsize=(20,8))
data.corr()['price'].sort_values(ascending=False).drop(['price']).plot(kind='bar',color='r')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# ### Data PreProcessing

# %%
numerical_columns=['price','Duration','Depart Times']
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in numerical_columns:
    if plotnumber<=30:
        ax=plt.subplot(4,2,plotnumber)
        sn.boxplot(data[column],color='pink')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
Q1 = data[numerical_columns].quantile(0.25)
Q3 = data[numerical_columns].quantile(0.75)
IQR = Q3-Q1
data_new1 = data[~((data[numerical_columns] < (Q1-1.5*IQR)) | (data[numerical_columns]> (Q3 + 1.5*Q3))).any(axis = 1)]

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in numerical_columns:
    if plotnumber<=30:
        ax=plt.subplot(4,2,plotnumber)
        sn.boxplot(data_new1[column],color='pink')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
print('Shape - Before and After:\n')
print('Shape Before'.ljust(20),":",data.shape)
print('Shape After'.ljust(20),":",data_new1.shape)
print('Percentage Loss'.ljust(20),":",((data.shape[0]-data_new1.shape[0])/data.shape[0])*100)
# Out:
# Shape - Before and After:
#
# Shape Before         : (30411, 8)
# Shape After          : (30134, 8)
# Percentage Loss      : 0.9108546249712276

# %%
features=data[['price','Duration']]
z=np.abs(zscore(features))
df=data[(z<3).all(axis=1)]

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in numerical_columns:
    if plotnumber<=30:
        ax=plt.subplot(4,2,plotnumber)
        sn.boxplot(df[column],color='pink')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
print('Shape - Before and After:\n')
print('Shape Before'.ljust(20),":",data.shape)
print('Shape After'.ljust(20),":",df.shape)
print('Percentage Loss'.ljust(20),":",((data.shape[0]-df.shape[0])/data.shape[0])*100)
# Out:
# Shape - Before and After:
#
# Shape Before         : (30411, 8)
# Shape After          : (29798, 8)
# Percentage Loss      : 2.015717996777482

# %%
features=df[['price','Duration']]
z=np.abs(zscore(features))
data_new=df[(z<3).all(axis=1)]

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in numerical_columns:
    if plotnumber<=30:
        ax=plt.subplot(4,2,plotnumber)
        sn.boxplot(data_new[column],color='pink')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
print('Shape - Before and After:\n')
print('Shape Before'.ljust(20),":",df.shape)
print('Shape After'.ljust(20),":",data_new.shape)
print('Percentage Loss'.ljust(20),":",((df.shape[0]-data_new.shape[0])/df.shape[0])*100)
# Out:
# Shape - Before and After:
#
# Shape Before         : (29798, 8)
# Shape After          : (29348, 8)
# Percentage Loss      : 1.5101684676823948

# %%
numerical_columns=['price','Duration']
for col in numerical_columns:
    if data[col].dtypes != 'object':
        percentile = data[col].quantile([0.01,0.98]).values
        data[col][data[col]<=percentile[0]]=percentile[0]
        data[col][data[col]>=percentile[1]]=percentile[1]

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in numerical_columns:
    if plotnumber<=30:
        ax=plt.subplot(4,2,plotnumber)
        sn.boxplot(data[column],color='pink')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### Skewness

# %%
numerical_columns=['Duration','Depart Times']
print(data[numerical_columns].skew())
print(len(data[numerical_columns].skew().loc[data[numerical_columns].skew()>0.55]))
# Out:
# Duration        0.803208
# Depart Times   -0.020484
# dtype: float64
# 1

# %%
df_new=data.copy()
df_new["Duration"]=np.log(df_new["Duration"])
print(df_new.skew().loc["Duration"])
# Out:
# -0.7105334521367792

# %% [markdown]
# ### Seperate feature and target variables

# %%
data
# Out:
#        Name  Depart Times  Departure  Arrival  Duration  No. of Stops  Days  \
# 0         4           950          5        3        70             0    37
# 1         4          1355          5        3        70             0    37
# 2         6           325          5        3        70             0    37
# 3         6           785          5        3        70             0    37
# 4         6           990          5        3        70             0    37
# ...     ...           ...        ...      ...       ...           ...   ...
# 32372     7           810         11        4      1425             1    82
# 32373     4          1430         11        4       480             1    82
# 32374     7          1235         11        4      1000             1    82
# 32375     6           465         11        4       410             1    82
# 32376     6           520         11        4       520             1    82
#
#         price
# 0      1802.0
# 1      1802.0
# 2      1802.0
# 3      1802.0
# 4      1802.0
# ...       ...
# 32372  7079.0
# 32373  7227.0
# 32374  7299.0
# 32375  7383.0
# 32376  7999.0
#
# [30411 rows x 8 columns]

# %%
data['price'] = data['price'].astype(int)
y = data[['price']].astype(int)
x = data.drop(columns = ['price'],axis=1)

# %% [markdown]
# ### Check for multicolinearity issue in dataset using VIF

# %%
vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(x.values,i) for i in range(x.shape[1]) ]
vif["Features"] = x.columns
vif
# Out:
#          vif      Features
# 0   4.486548          Name
# 1   0.281002  Depart Times
# 2   3.787488     Departure
# 3   3.465556       Arrival
# 4   0.335942      Duration
# 5   6.704946  No. of Stops
# 6  10.949725          Days

# %% [markdown]
# ### Feature Scaling

# %%
scaler =StandardScaler()
x[['Duration','Depart Times']]= scaler.fit_transform(x[['Duration','Depart Times']])

# %% [markdown]
# ### model building
# below is the code to find best random state to split dataset into train and test for a specific model

# %%
def besttrain(model,x,y):
    random=0
    score=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state = i,test_size=0.20,shuffle=True)
        model.fit(x_train,y_train)
        tmp=r2_score(y_test,model.predict(x_test))
        if tmp>score:
            score=tmp
            random=i
    return random

# %% [markdown]
# Below are all the models through which we need to iterate through to find the best model

# %%
models=[GradientBoostingRegressor(),NuSVR(),LinearRegression(),Ridge(),RidgeCV(),BayesianRidge(),SGDRegressor(),SVR(),
        AdaBoostRegressor(),LinearSVR(),KNeighborsRegressor(),RandomForestRegressor(),BaggingRegressor(),
       DecisionTreeRegressor(),LGBMRegressor(), XGBRFRegressor(),XGBRegressor()]

# %% [markdown]
# Below is the code to iterate all the models, train them and display their acc

# %%
for i in models:
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state = 42,test_size=0.20)
    scores=cross_val_score(i,x_train,y_train,cv=5,scoring='r2',n_jobs=-1)
    score=np.mean(scores)
    i.fit(x_train,y_train)
    y_pred=i.predict(x_test)
    if r2_score(y_test,y_pred)>score:
        diff=r2_score(y_test,y_pred)-score
    else:
        diff=score-r2_score(y_test,y_pred)
    print('*'*10)
    print(i)
    print('score',score)
    print('r2',r2_score(y_test,y_pred))
    print('diff',diff)
    print('mae',mean_absolute_error(y_test, y_pred))
    print('rmse',np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# **********
# GradientBoostingRegressor()
# score 0.5935661066654945
# r2 0.6044687816802756
# diff 0.010902675014781149
# mae 1101.6571879555527
# rmse 1525.7602367719344
# **********
# NuSVR()
# score 0.0337493086440227
# r2 0.03957546725737893
# diff 0.005826158613356225
# mae 1779.4987556896776
# rmse 2377.5383530229087
# **********
# LinearRegression()
# score 0.4002298126195405
# r2 0.3949525310720098
# diff 0.00527728154753071
# mae 1413.7940526596606
# rmse 1887.0813964023744
# **********
# Ridge()
# score 0.40022978981564317
# r2 0.39495379572371814
# diff 0.005275994091925029
# mae 1413.7902161538725
# rmse 1887.0794242414438
# **********
# RidgeCV(alphas=array([ 0.1,  1. , 10. ]))
# score 0.4002297898200046
# r2 0.39495379574539
# diff 0.005275994074614598
# mae 1413.7902159496864
# rmse 1887.0794242076474
# **********
# BayesianRidge()
# score 0.4002293794223245
# r2 0.394959604148014
# diff 0.005269775274310495
# mae 1413.7723353537956
# rmse 1887.0703662685116
# **********
# SGDRegressor()
# score -0.08565499502034915
# r2 0.2183003950338901
# diff 0.3039553900542392
# mae 1546.411594968584
# rmse 2144.943491504342
# **********
# SVR()
# score 0.003720092825106658
# r2 0.009632388556150118
# diff 0.00591229573104346
# mae 1754.6791832733115
# rmse 2414.3160605582925
# **********
# AdaBoostRegressor()
# score 0.31651036145363437
# r2 0.30789576483723213
# diff 0.008614596616402237
# mae 1636.101955141694
# rmse 2018.2811419934335
# **********
# LinearSVR()
# score 0.1484327758738762
# r2 0.17895837659160962
# diff 0.030525600717733414
# mae 1503.9165908391583
# rmse 2198.257159336193
# **********
# KNeighborsRegressor()
# score 0.6095780561450945
# r2 0.627739195308767
# diff 0.018161139163672457
# mae 994.8552359033372
# rmse 1480.197153993386
# **********
# RandomForestRegressor()
# score 0.7723723189581413
# r2 0.7977619141063346
# diff 0.025389595148193278
# mae 643.1670897242428
# rmse 1091.0066105531755
# **********
# BaggingRegressor()
# score 0.747179734033763
# r2 0.7706485771691294
# diff 0.023468843135366346
# mae 688.562801673412
# rmse 1161.8408131492497
# **********
# DecisionTreeRegressor()
# score 0.5968127789647576
# r2 0.6369974705382482
# diff 0.04018469157349058
# mae 724.6783823771167
# rmse 1461.6747159122879
# **********
# LGBMRegressor()
# score 0.716022843089732
# r2 0.7308414619512323
# diff 0.014818618861500377
# mae 883.9038548775145
# rmse 1258.6355359208558
# **********
# XGBRFRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                colsample_bytree=1, gamma=0, gpu_id=-1, importance_type='gain',
#                interaction_constraints='', max_delta_step=0, max_depth=6,
#                min_child_weight=1, missing=nan, monotone_constraints='()',
#                n_estimators=100, n_jobs=8, num_parallel_tree=100,
#                objective='reg:squarederror', random_state=0, reg_alpha=0,
#                scale_pos_weight=1, tree_method='exact', validate_parameters=1,
#                verbosity=None)
# score 0.5308090663007289
# r2 0.5285421442143363
# diff 0.0022669220863925643
# mae 1202.0337420966346
# rmse 1665.7788639498256
# **********
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)
# score 0.7693604169285831
# r2 0.7867591783579262
# diff 0.017398761429343046
# mae 770.6000802678026
# rmse 1120.2916076025722

# %% [markdown]
# ### Top models are:
#     XGBRegressor
#     RandomForestRegressor

# %%
parameters={"n_estimators":[10,100,500],'criterion':['mse', 'mae'],'max_features':['auto', 'sqrt', 'log2']}
clf = RandomizedSearchCV(RandomForestRegressor(), parameters, cv=10,scoring="r2",n_jobs=-1,verbose=1)
clf.fit(x,y)
clf.best_params_
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 52.0min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed: 155.2min finished
# {'n_estimators': 500, 'max_features': 'sqrt', 'criterion': 'mse'}

# %%
parameters={'n_estimators': [100, 80, 60, 55, 51, 45],  
              'max_depth': [7, 8],
              'reg_lambda' :[0.26, 0.25, 0.2]}
clf = GridSearchCV(XGBRegressor(), parameters, cv=10,scoring="r2",n_jobs=-1,verbose=1)
clf.fit(x,y)
clf.best_params_
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 360 out of 360 | elapsed:  2.2min finished
# {'max_depth': 7, 'n_estimators': 100, 'reg_lambda': 0.2}

# %%
besttrain(RandomForestRegressor(criterion='mse',max_features='sqrt',n_estimators=500),x,y)
# Out:
# 76

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=76, test_size=0.2)
stack = StackingCVRegressor(regressors=(XGBRegressor(max_depth=7,n_estimators=100,reg_lambda=0.2), 
                                        RandomForestRegressor(criterion='mse',max_features='sqrt',n_estimators=500)
                                       ),
                            meta_regressor=RandomForestRegressor(criterion='mse',max_features='sqrt',n_estimators=500), 
                            cv=12,
                            use_features_in_secondary=True,
                            store_train_meta_features=True,
                            shuffle=False)
stack.fit(X_train, y_train)
pred = stack.predict(X_test)
score = r2_score(y_test, pred)
print('r2 score test',score)
pred = stack.predict(X_train)
score = r2_score(y_train, pred)
print('r2 score train',score)
# Out:
# r2 score test 0.8385762064113143
# r2 score train 0.9408486110278014

# %%
y_pred=stack.predict(X_test)
score=r2_score(y_test,y_pred)
print('coeff of determination is:',score)
print('mean absolute error:',mean_absolute_error(y_test,y_pred))
print('mean squared error:',mean_squared_error(y_test,y_pred))
print('root mean square error:',np.sqrt(mean_squared_error(y_test,y_pred)))
scores =cross_val_score(StackingCVRegressor(regressors=(XGBRegressor(max_depth=7,n_estimators=100,reg_lambda=0.2), 
                                        RandomForestRegressor(criterion='mse',max_features='sqrt',n_estimators=500)
                                       ),
                            meta_regressor=RandomForestRegressor(criterion='mse',max_features='sqrt',n_estimators=500), 
                            cv=12,
                            use_features_in_secondary=True,
                            store_train_meta_features=True,
                            shuffle=False),x,y,cv=5,n_jobs=-1,verbose=1)
print('cross val score',scores.mean())
print('std err',scores.std())
# Out:
# coeff of determination is: 0.8385762064113143
# mean absolute error: 608.7227173774688
# mean squared error: 961373.9033483187
# root mean square error: 980.4967635583091
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  4.7min remaining:  7.0min
# cross val score 0.507604522873206
# std err 0.1564602377608127
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  4.8min finished

# %%
y_pred=stack.predict(x)
score=r2_score(y,y_pred)
print('coeff of determination is:',score)
print('mean absolute error:',mean_absolute_error(y,y_pred))
print('mean squared error:',mean_squared_error(y,y_pred))
print('root mean square error:',np.sqrt(mean_squared_error(y,y_pred)))
# Out:
# coeff of determination is: 0.9206876861054203
# mean absolute error: 405.94231568597513
# mean squared error: 479248.0172483002
# root mean square error: 692.2774135043697

# %%
y_pred=stack.predict(x)
data['Pred']=[round(i) for i in y_pred]
data
# Out:
#        Name  Depart Times  Departure  Arrival  Duration  No. of Stops  Days  \
# 0         4           950          5        3        70             0    37
# 1         4          1355          5        3        70             0    37
# 2         6           325          5        3        70             0    37
# 3         6           785          5        3        70             0    37
# 4         6           990          5        3        70             0    37
# ...     ...           ...        ...      ...       ...           ...   ...
# 32372     7           810         11        4      1425             1    82
# 32373     4          1430         11        4       480             1    82
# 32374     7          1235         11        4      1000             1    82
# 32375     6           465         11        4       410             1    82
# 32376     6           520         11        4       520             1    82
#
#        price  Pred
# 0       1802  1803
# 1       1802  1841
# 2       1802  1829
# 3       1802  1873
# 4       1802  1820
# ...      ...   ...
# 32372   7079  7021
# 32373   7227  7623
# 32374   7299  7073
# 32375   7383  7901
# 32376   7999  6501
#
# [30411 rows x 9 columns]

# %%
data['diff']=data['Pred']-data['price']
data
# Out:
#        Name  Depart Times  Departure  Arrival  Duration  No. of Stops  Days  \
# 0         4           950          5        3        70             0    37
# 1         4          1355          5        3        70             0    37
# 2         6           325          5        3        70             0    37
# 3         6           785          5        3        70             0    37
# 4         6           990          5        3        70             0    37
# ...     ...           ...        ...      ...       ...           ...   ...
# 32372     7           810         11        4      1425             1    82
# 32373     4          1430         11        4       480             1    82
# 32374     7          1235         11        4      1000             1    82
# 32375     6           465         11        4       410             1    82
# 32376     6           520         11        4       520             1    82
#
#        price  Pred  diff
# 0       1802  1803     1
# 1       1802  1841    39
# 2       1802  1829    27
# 3       1802  1873    71
# 4       1802  1820    18
# ...      ...   ...   ...
# 32372   7079  7021   -58
# 32373   7227  7623   396
# 32374   7299  7073  -226
# 32375   7383  7901   518
# 32376   7999  6501 -1498
#
# [30411 rows x 10 columns]

# %%
max(data['diff']),min(data['diff'])
# Out:
# (5768, -7665)

# %%
data.sort_values(by=['diff'],ascending=False)
# Out:
#        Name  Depart Times  Departure  Arrival  Duration  No. of Stops  Days  \
# 22824     2           355          7        8       825             1    37
# 2191      2           420          2        4       425             1    37
# 23204     7           810         11        2      1435             2    37
# 18961     6           430          1        5       405             1    67
# 1323      7           915          3        5      1005             2    37
# ...     ...           ...        ...      ...       ...           ...   ...
# 26930     3           390         11        8       925             1    61
# 8492      6           315          2        1       205             1    67
# 28694     3           390         11        8       925             1    67
# 1163      6          1190          3        8       310             1    37
# 6314      6           315          2        1       205             1    61
#
#        price   Pred  diff
# 22824   5465  11233  5768
# 2191    5297  10359  5062
# 23204   7054  11537  4483
# 18961   1802   6217  4415
# 1323    4024   8221  4197
# ...      ...    ...   ...
# 26930  13064   6301 -6763
# 8492   10367   3572 -6795
# 28694  13064   6194 -6870
# 1163   12504   5420 -7084
# 6314   11557   3892 -7665
#
# [30411 rows x 10 columns]

# %%
sn.lmplot(x='price',y='Pred',data=data,palette='rainbow')

# %%
plt.plot(X_test,y_test,'r*')
plt.plot(X_test,stack.predict(X_test),'b.')
plt.show()

# %%
plt.plot(x,y,'r*')
plt.plot(x,data['Pred'],'b.')
plt.show()

# %%
sn.distplot(data['price'])
sn.distplot(data['Pred'])
# Out:
# <AxesSubplot:xlabel='Pred', ylabel='Density'>

# %%
joblib.dump(stack,'Flight.pkl')
# Out:
# ['Flight.pkl']
